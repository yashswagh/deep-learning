# %% [markdown]
# <a href="https://colab.research.google.com/github/yashswagh/deep-learning/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from datetime import timedelta
import warnings
import os
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/DL DataSets/Copy of Train.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['Gender']= label_encoder.fit_transform(df['Gender'])
  
df['Gender'].unique()
# Out:
# array([1, 0])

# %%
df1['Ever_Married']= label_encoder.fit_transform(df1['Ever_Married'])
  
df1['Ever_Married'].unique()
# Out:
# array([0, 1, 2])

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = imputer.fit(df1[['Ever_Married']])
df1['Ever_Married'] = imputer.transform(df1[['Ever_Married']])

# %%
def plot_pie(feature, df=None):
    data = df
    plot_data = data.groupby([feature, 'Segmentation'])[feature].agg({'count'}).reset_index()

    fig = px.sunburst(plot_data, path = [feature, 'Segmentation'], values = 'count', color = feature, 
                      title = 'Affect of %s on Customer Segmentation'%feature, width = 600, height = 600)

    fig.update_layout(plot_bgcolor = 'white', title_font_family = 'Calibri Black', title_font_color = '#221f1f', 
                      title_font_size = 22, title_x = 0.5)

    fig.update_traces(textinfo = 'label + percent parent')
    fig.show()

# %%
for feature in ['Gender', 'Ever_Married', 'Graduated', 'Spending_Score']:
    plot_pie(feature, df=df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.displot(data=df.Age.values)

# %%
sns.catplot(x="Segmentation",data=df,kind="count",height=7).set(title='Customers')

# %%
sns.catplot(x="Gender",hue="Segmentation",data=df,kind="count",height=7).set(title='Segmention/Gender')

# %%
sns.catplot(x="Ever_Married",hue="Segmentation",data=df,kind="count",height=7).set(title='Segmentación/Married')

# %%
sns.catplot(x="Profession",hue="Segmentation",data=df,kind="count",height=7,aspect=2).set(title='Segmentation/Profession')

# %%
sns.catplot(x="Spending_Score",hue="Segmentation",data=df,kind="count",height=7).set(title='Segmentation/Spending_Score')

# %%
sns.catplot(x="Var_1",hue="Segmentation",data=df,kind="count",height=7).set(title='Segmentation/Var1')

# %%
sns.set(rc={'figure.figsize':(15,12)})
sns.heatmap(df.corr(),annot=True)

# %%
def plot_numerical(feature, figsize=None, df=None):
    data = df
    fig = plt.figure(figsize=(10,6))

    sns.kdeplot(data[data['Segmentation']=='A'][feature])
    sns.kdeplot(data[data['Segmentation']=='B'][feature])
    sns.kdeplot(data[data['Segmentation']=='C'][feature])
    sns.kdeplot(data[data['Segmentation']=='D'][feature])

    fig.legend(labels=['Segmentation A', 'Segmentation B', 'Segmentation C', 'Segmentation D'])
    plt.title('Based on %s'%feature)
    plt.show()

# %%
for feature in ['Age']:
    plot_numerical(feature, df=df)

# %%
for feature in ['Work_Experience']:
    plot_numerical(feature, df=df)

# %%
for feature in ['Family_Size']:
    plot_numerical(feature, df=df)

# %%
df.groupby(['Graduated','Spending_Score'])[['Spending_Score']].count()#.plot(kind='bar')
# Out:
#                           Spending_Score
# Graduated Spending_Score
# No        Average                    503
#           High                       425
#           Low                       2094
# Yes       Average                   1450
#           High                       780
#           Low                       2738

# %%
df.groupby(['Gender','Spending_Score'])[['Spending_Score']].count()
# Out:
#                        Spending_Score
# Gender Spending_Score
# Female Average                    831
#        High                       490
#        Low                       2330
# Male   Average                   1143
#        High                       726
#        Low                       2548

# %%
df.groupby(['Gender','Profession'])[['Profession']].count().plot(kind = 'bar')

# %%
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
k=df.groupby(['Gender','Profession'])[['Profession']].count()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-4e52017f50d9> in <module>()
# ----> 1 df.groupby(['Profession','Age']),[['Age']].count()
#
# TypeError: count() takes exactly one argument (0 given)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-a8a316a274cd> in <module>()
# ----> 1 l.count() #.plot(kind='bar')
#
# TypeError: count() takes exactly one argument (0 given)
